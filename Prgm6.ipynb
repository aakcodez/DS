# %% [markdown]
# Random Forest

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix,accuracy_score

# %%
df = pd.read_excel("C:/Users/user1/Downloads/random_forest_dataset.xlsx")
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = pd.read_excel("C:/Users/user1/Downloads/random_forest_dataset.xlsx")
#       2 df.head()
#
# NameError: name 'pd' is not defined

# %%
df = pd.read_excel("C:/Users/user1/Downloads/random_forest_dataset.xlsx", header=1)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df = pd.read_excel("C:/Users/user1/Downloads/random_forest_dataset.xlsx", header=1)
#       2 df.head()
#
# NameError: name 'pd' is not defined

# %%
df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df.isnull().sum()
#
# NameError: name 'df' is not defined

# %%
# handle outliers
df.dropna(inplace=True)
# there is this extra space after the column names
x = df.drop(['Sl No ',"USN ","Name ","Title ","Grade"],axis=1)
y = df.Grade
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # handle outliers
# ----> 2 df.dropna(inplace=True)
#       3 # there is this extra space after the column names
#       4 x = df.drop(['Sl No ',"USN ","Name ","Title ","Grade"],axis=1)
#
# NameError: name 'df' is not defined

# %%
x.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 x.head()
#
# NameError: name 'x' is not defined

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
y = label_encoder.fit_transform(df['Grade'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       1 from sklearn.preprocessing import LabelEncoder
#       3 label_encoder = LabelEncoder()
# ----> 4 y = label_encoder.fit_transform(df['Grade'])
#
# NameError: name 'df' is not defined

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)
rf = RandomForestClassifier(random_state=42)
rf.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)
#       2 rf = RandomForestClassifier(random_state=42)
#       3 rf.fit(x_train,y_train)
#
# NameError: name 'train_test_split' is not defined

# %%
feature_importances = pd.Series(rf.feature_importances_, index=x.columns).sort_values(ascending=False)
print(feature_importances)
plt.figure(figsize=(10, 6))
feature_importances.plot(kind='bar')
plt.xlabel('Feature')
plt.ylabel('Importance')
plt.title('Feature Importance')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 feature_importances = pd.Series(rf.feature_importances_, index=x.columns).sort_values(ascending=False)
#       2 print(feature_importances)
#       3 plt.figure(figsize=(10, 6))
#
# NameError: name 'pd' is not defined

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier

# Define the parameter grid correctly
param_grid = {
    'n_estimators': [100, 200, 300],  # Fixed key name
    'max_depth': [10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]  # Fixed "min_samples_lear" typo
}

grid_search = GridSearchCV(estimator=rf, param_grid = param_grid, cv=5, n_jobs=-1,verbose=1)

grid_search.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 12
#       4 # Define the parameter grid correctly
#       5 param_grid = {
#       6     'n_estimators': [100, 200, 300],  # Fixed key name
#       7     'max_depth': [10, 20, 30],
#       8     'min_samples_split': [2, 5, 10],
#       9     'min_samples_leaf': [1, 2, 4]  # Fixed "min_samples_lear" typo
#      10 }
# ---> 12 grid_search = GridSearchCV(estimator=rf, param_grid = param_grid, cv=5, n_jobs=-1,verbose=1)
#      14 grid_search.fit(x_train,y_train)
#
# NameError: name 'rf' is not defined

# %%
best_params = grid_search.best_params_
best_params
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 best_params = grid_search.best_params_
#       2 best_params
#
# NameError: name 'grid_search' is not defined

# %%
best_rf = RandomForestClassifier(random_state=42,**best_params)
best_rf.fit(x_train,y_train)
y_pred = best_rf.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 best_rf = RandomForestClassifier(random_state=42,**best_params)
#       2 best_rf.fit(x_train,y_train)
#       3 y_pred = best_rf.predict(x_test)
#
# NameError: name 'best_params' is not defined

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score, confusion_matrix,
    classification_report
)
# Print metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print(f"🔹 Accuracy: {accuracy:.4f}")
print(f"🔹 Precision: {precision:.4f}")
print(f"🔹 Recall: {recall:.4f}")
print(f"🔹 F1 Score: {f1:.4f}")

# Print classification report
print("\n🔹 Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 8
#       3 from sklearn.metrics import (
#       4     accuracy_score, precision_score, recall_score, f1_score, confusion_matrix,
#       5     classification_report
#       6 )
#       7 # Print metrics
# ----> 8 accuracy = accuracy_score(y_test, y_pred)
#       9 precision = precision_score(y_test, y_pred, average='weighted')
#      10 recall = recall_score(y_test, y_pred, average='weighted')
#
# NameError: name 'y_test' is not defined

# %%
# Confusion matrix
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=np.unique(y_test), yticklabels=np.unique(y_test))
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 # Confusion matrix
# ----> 2 cm = confusion_matrix(y_test, y_pred)
#       4 plt.figure(figsize=(6,4))
#       5 sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=np.unique(y_test), yticklabels=np.unique(y_test))
#
# NameError: name 'y_test' is not defined

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(80,40))
plot_tree(best_rf.estimators_[5], feature_names = x.columns,class_names=['A', 'B', 'C', 'S'],filled=True);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 from sklearn.tree import plot_tree
#       2 plt.figure(figsize=(80,40))
# ----> 3 plot_tree(best_rf.estimators_[5], feature_names = x.columns,class_names=['A', 'B', 'C', 'S'],filled=True);
#
# NameError: name 'best_rf' is not defined

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(80,40))
plot_tree(best_rf.estimators_[7], feature_names = x.columns,class_names=['A', 'B', 'C', 'S'],filled=True);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 from sklearn.tree import plot_tree
#       2 plt.figure(figsize=(80,40))
# ----> 3 plot_tree(best_rf.estimators_[7], feature_names = x.columns,class_names=['A', 'B', 'C', 'S'],filled=True);
#
# NameError: name 'best_rf' is not defined

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import  ConfusionMatrixDisplay
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from scipy.stats import randint
param_dist = {
  'n_estimators': randint(100, 500),
  'max_depth': randint(3, 15),
  'min_samples_split': randint(2, 10),
  'min_samples_leaf': randint(1, 5)
}


# Create a random forest classifier
rf = RandomForestClassifier(random_state=42, n_jobs=-1)

# Use random search to find the best hyperparameters
rand_search = RandomizedSearchCV(
  rf, param_distributions=param_dist,
  n_iter=10, cv=5, scoring='accuracy',
  n_jobs=-1, random_state=42)
rand_search.fit(x, y)

# Create a variable for the best model
best_rf = rand_search.best_estimator_

# Print the best hyperparameters
print('Best hyperparameters:',  rand_search.best_params_)
    # Generate predictions with the best model
y_pred = best_rf.predict(x_test)

# Create the confusion matrix
cm = confusion_matrix(y_test, y_pred)

ConfusionMatrixDisplay(confusion_matrix=cm).plot();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 21
#      16 # Use random search to find the best hyperparameters
#      17 rand_search = RandomizedSearchCV(
#      18   rf, param_distributions=param_dist,
#      19   n_iter=10, cv=5, scoring='accuracy',
#      20   n_jobs=-1, random_state=42)
# ---> 21 rand_search.fit(x, y)
#      23 # Create a variable for the best model
#      24 best_rf = rand_search.best_estimator_
#
# NameError: name 'x' is not defined

# %%
C:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
  warnings.warn(
Best hyperparameters: {'max_depth': 3, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 269}
# Out:
#   Cell In[21], line 1
#     C:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#        ^
# SyntaxError: unexpected character after line continuation character
